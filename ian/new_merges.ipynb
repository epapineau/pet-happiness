# %%
import pandas as pd

# %%
world_gdp = pd.read_csv('../data/country-GDP-2017.csv',encoding = "ISO-8859-1", names = ['Country', 'Country Code', 'GDP'], skiprows = 1)
world_gdp.head(1)
# Out:
#   Country Country Code           GDP
# 0   Aruba          ABW  2.081530e+10

# %%
# world_gdp['Country Name']

# %%
world_happiness = pd.read_csv('../data/world_happiness_2017.csv')
world_happiness.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %%
merged_df = pd.merge(world_gdp, world_happiness, on = ['Country', 'Country'])
merged_df.head()
# Out:
#                 Country Country Code           GDP  Happiness.Rank  \
# 0           Afghanistan          AFG  1.240000e+11             141
# 1                Angola          AGO  1.303935e+10             140
# 2               Albania          ALB  3.012914e+09             109
# 3  United Arab Emirates          ARE  6.380000e+11              21
# 4             Argentina          ARG  1.153659e+10              24
#
#    Happiness.Score  Whisker.high  Whisker.low  Economy..GDP.per.Capita.  \
# 0            3.794      3.873661     3.714338                  0.401477
# 1            3.795      3.951642     3.638358                  0.858428
# 2            4.644      4.752464     4.535536                  0.996193
# 3            6.648      6.722047     6.573952                  1.626343
# 4            6.599      6.690085     6.507915                  1.185295
#
#      Family  Health..Life.Expectancy.   Freedom  Generosity  \
# 0  0.581543                  0.180747  0.106180    0.311871
# ...

# %%
merged_df.to_csv('../data/happiness_and_gdp.csv')

# %%
world_gdp = pd.read_csv('../data/country-GDP-2017.csv',encoding = "ISO-8859-1", names = ['Country', 'Country Code', 'GDP'], skiprows = 1)
world_happiness = pd.read_csv('../data/world_happiness_2017.csv')
merged_df = pd.merge(world_gdp, world_happiness, on = ['Country', 'Country'])
merged_df.head()
# Out:
#                 Country Country Code           GDP  Happiness.Rank  \
# 0           Afghanistan          AFG  1.240000e+11             141
# 1                Angola          AGO  1.303935e+10             140
# 2               Albania          ALB  3.012914e+09             109
# 3  United Arab Emirates          ARE  6.380000e+11              21
# 4             Argentina          ARG  1.153659e+10              24
#
#    Happiness.Score  Whisker.high  Whisker.low  Economy..GDP.per.Capita.  \
# 0            3.794      3.873661     3.714338                  0.401477
# 1            3.795      3.951642     3.638358                  0.858428
# 2            4.644      4.752464     4.535536                  0.996193
# 3            6.648      6.722047     6.573952                  1.626343
# 4            6.599      6.690085     6.507915                  1.185295
#
#      Family  Health..Life.Expectancy.   Freedom  Generosity  \
# 0  0.581543                  0.180747  0.106180    0.311871
# ...

# %%
merged_df.to_csv('gdp_and_happine')

# %%
gdp_per_capita = pd.read_csv('../data/country-gdp-per-capita.csv')
country_gdp = pd.read_csv('../data/country-GDP-2017.csv')

# %%
gdp_df = pd.merge(gdp_per_capita, country_gdp, on = ['Country Name', 'Country Name'])
gdp_df.head()
# Out:
#   Country Name       GDP/CAP           GDP
# 0        Aruba           NaN           NaN
# 1  Afghanistan    585.850064  2.081530e+10
# 2       Angola   4170.312280  1.242094e+11
# 3      Albania   4537.862492  1.303935e+10
# 4      Andorra  39146.548840  3.012914e+09

# %%
world_happiness = pd.read_csv('../data/world_happiness_2017.csv')
world_happiness.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
gdp_per_capita = pd.read_csv('../data/country-gdp-per-capita.csv')
country_gdp = pd.read_csv('../data/country-GDP-2017.csv')
gdp_df = pd.merge(gdp_per_capita, country_gdp, on = ['Country Name', 'Country Name'])
gdp_df.head()
# Out:
#   Country Name       GDP/CAP           GDP
# 0        Aruba           NaN           NaN
# 1  Afghanistan    585.850064  2.081530e+10
# 2       Angola   4170.312280  1.242094e+11
# 3      Albania   4537.862492  1.303935e+10
# 4      Andorra  39146.548840  3.012914e+09

# %%
# world_happiness = pd.merge(gdp_df, world_happiness, on = ['Country Name', 'Country'])
world_happiness['Country']
# Out:
# 0                        Norway
# 1                       Denmark
# 2                       Iceland
# 3                   Switzerland
# 4                       Finland
# 5                   Netherlands
# 6                        Canada
# 7                   New Zealand
# 8                        Sweden
# 9                     Australia
# 10                       Israel
# 11                   Costa Rica
# 12                      Austria
# 13                United States
# 14                      Ireland
# 15                      Germany
# 16                      Belgium
# 17                   Luxembourg
# 18               United Kingdom
# 19                        Chile
# 20         United Arab Emirates
# 21                       Brazil
# 22               Czech Republic
# 23                    Argentina
# 24                       Mexico
# 25                    Singapore
# 26                        Malta
# 27                      Uruguay
# 28                    Guatemala
# ...
