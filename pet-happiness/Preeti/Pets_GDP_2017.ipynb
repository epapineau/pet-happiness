# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
petgdp_2017 = pd.read_csv('../data/petgdp_2017.csv')
petgdp_2017.head()
# Out:
#    Pet      Country  Population  GDP(US Billion Dollar)
# 0  Dog          USA    69929000                19362.13
# 1  Dog        China    27400000                11937.56
# 2  Dog       Russia    12520000                 1469.34
# 3  Dog        Japan    12000000                 4884.49
# 4  Dog  Philippines    11600000                  313.60

# %%
dog_data = petgdp_2017.query('Pet == "Dog"')
dog_data.head()
# Out:
#    Pet      Country  Population  GDP(US Billion Dollar)
# 0  Dog          USA    69929000                19362.13
# 1  Dog        China    27400000                11937.56
# 2  Dog       Russia    12520000                 1469.34
# 3  Dog        Japan    12000000                 4884.49
# 4  Dog  Philippines    11600000                  313.60

# %%
cat_data = petgdp_2017.query('Pet == "Cat"')
cat_data.head()
# Out:
#     Pet Country  Population  GDP(US Billion Dollar)
# 19  Cat     USA    74059000                19362.13
# 20  Cat   China    53100000                11937.56
# 21  Cat  Russia    17800000                 1469.34
# 22  Cat  Brazil    12466000                 2080.92
# 23  Cat  France    11480000                 2583.00

# %%
bird_data = petgdp_2017.query('Pet == "Bird"')
bird_data.head()
# Out:
#      Pet    Country  Population  GDP(US Billion Dollar)
# 39  Bird     Brazil   191001000                 2080.92
# 40  Bird      Italy    13000000                 1921.14
# 41  Bird        USA     8300000                19362.13
# 42  Bird  Australia     7800000                 1390.15
# 43  Bird     France     6200000                 2583.00

# %%
fish_data = petgdp_2017.query('Pet == "Fish"')
fish_data.head()
# Out:
#      Pet    Country  Population  GDP(US Billion Dollar)
# 59  Fish        USA    57750000                19362.13
# 60  Fish     France    37300000                 2583.00
# 61  Fish     Brazil    26500000                 2080.92
# 62  Fish  Australia    20500000                 1390.15
# 63  Fish         UK    20000000                 2565.05

# %%
x = dog_data['GDP(US Billion Dollar)']
y = dog_data['Pet']
s = dog_data['Country']

# %%
plt.scatter(x, y)
plt.show()
