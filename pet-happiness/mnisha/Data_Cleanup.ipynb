# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
world_urban_gdp = pd.read_csv('world_urban_population_gdp.csv')
world_urban_gdp.head()
# Out:
#   Country Name Country Code                 Indicator Name     Indicator Code  \
# 0        Aruba          ABW  Urban population (% of total)  SP.URB.TOTL.IN.ZS
# 1  Afghanistan          AFG  Urban population (% of total)  SP.URB.TOTL.IN.ZS
# 2       Angola          AGO  Urban population (% of total)  SP.URB.TOTL.IN.ZS
# 3      Albania          ALB  Urban population (% of total)  SP.URB.TOTL.IN.ZS
# 4      Andorra          AND  Urban population (% of total)  SP.URB.TOTL.IN.ZS
#
#      1960    1961    1962    1963    1964    1965   ...      2008    2009  \
# 0  50.776  50.761  50.746  50.730  50.715  50.700   ...    43.783  43.421
# 1   8.401   8.684   8.976   9.276   9.586   9.904   ...    23.320  23.528
# 2  10.435  10.798  11.204  11.624  12.058  12.504   ...    58.282  59.034
# 3  30.705  30.943  31.015  31.086  31.158  31.230   ...    49.991  51.076
# 4  58.450  60.983  63.462  65.872  68.205  70.445   ...    89.004  88.912
#
# ...

# %%
clean_world_urban_df = world_urban_gdp[['Country Name','Country Code','2017']]
clean_world_urban_df.head()
#df1 = df[['a','b']]
# Out:
#   Country Name Country Code    2017
# 0        Aruba          ABW  43.293
# 1  Afghanistan          AFG  25.250
# 2       Angola          AGO  64.839
# 3      Albania          ALB  59.383
# 4      Andorra          AND  88.150

# %%
clean_world_urban_df.columns = ['country_name','country_code','urban_gdp_percent']
clean_world_urban_df.head()
# Out:
#   country_name country_code  urban_gdp_percent
# 0        Aruba          ABW             43.293
# 1  Afghanistan          AFG             25.250
# 2       Angola          AGO             64.839
# 3      Albania          ALB             59.383
# 4      Andorra          AND             88.150

# %%
clean_world_urban_df.to_csv('world_urban_gdp.csv')
